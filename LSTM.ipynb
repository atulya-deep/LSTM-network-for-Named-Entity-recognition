# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.utils import pad_sequences
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras import Model, Input
from keras.layers import LSTM, Embedding, Dense
from keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv("ner_datasetreference.csv", encoding="latin1")
data=data.fillna(method="ffill")
data.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
print("Unique words in corpus:",data['Word'].nunique())
print("Unique tags in corpus:",data['Tag'].nunique())
# Out:
# Unique words in corpus: 35178
# Unique tags in corpus: 17

# %%
words=list(set(data["Word"].values))
words.append("ENDPAD")
num_words=len(words)

# %%
tags=list(set(data["Tag"].values))
num_tags=len(tags)

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent=1
        self.data=data
        self.empty=False
        agg_func=lambda s:[(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                           s["POS"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped=self.data.groupby("Sentence #").apply(agg_func)
        self.sentences=[s for s in self.grouped]
    
    def get_next(self):
        try:
            s=self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent+=1
            return s
        except:
            return None

# %%
getter=SentenceGetter(data)
sentences=getter.sentences

# %%
sentences[0]
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %%
word2idx={w:i + 1 for i, w in enumerate(words)}
tag2idx={t:i for i, t in enumerate(tags)}

# %%
word2idx
# Out:
# {'Bud': 1,
#  'blockades': 2,
#  'unsaturated': 3,
#  'padded': 4,
#  'Publication': 5,
#  'anti-government': 6,
#  'torchbearer': 7,
#  'regimes': 8,
#  'volt': 9,
#  'credited': 10,
#  'shows': 11,
#  'penalize': 12,
#  'Realtors': 13,
#  'Lausanne': 14,
#  'Kahar': 15,
#  'apologies': 16,
#  'Restore': 17,
#  'punctuated': 18,
#  'dad': 19,
#  '03-Jun': 20,
#  'glided': 21,
#  '706': 22,
#  'Amplio': 23,
#  'measuring': 24,
#  'Finland': 25,
#  'hindering': 26,
#  'dozens': 27,
#  'Bids': 28,
#  'Guehenno': 29,
#  'Six-party': 30,
#  'partner': 31,
#  'coercion': 32,
#  'export-oriented': 33,
#  'interfere': 34,
#  'shepherd': 35,
#  'Brigades': 36,
#  'Sur': 37,
#  'tradition': 38,
#  'Merimee': 39,
#  'everyday': 40,
#  'Sepat': 41,
#  '5,19,000': 42,
#  'discontinued': 43,
#  'accepts': 44,
#  'export-led': 45,
#  'Enkhbayar': 46,
#  'playlists': 47,
#  'climb': 48,
#  'anticipate': 49,
#  'Demand': 50,
#  'Jalbire': 51,
#  '150': 52,
#  'Piracy': 53,
#  'designates': 54,
#  'couple': 55,
#  'metric': 56,
#  'Ma': 57,
#  'fining': 58,
#  'Democrat': 59,
#  'Aubenas': 60,
#  'Polynesian': 61,
#  'Ravi': 62,
#  'Colleen': 63,
#  'editor': 64,
#  'Cabbage': 65,
#  '80-kilometer': 66,
#  'vaccines': 67,
#  'flowing': 68,
#  'Vivanco': 69,
#  'worshipped': 70,
#  'bag': 71,
#  'Nest': 72,
#  'unsatisfactory': 73,
#  'then-Georgian': 74,
#  'ninth-century': 75,
#  'Referenda': 76,
#  'consumer': 77,
#  'airborne': 78,
#  'riverine': 79,
#  'Implementation': 80,
#  'Ahmadi': 81,
#  'Nassif': 82,
#  'shrinks': 83,
#  'markedly': 84,
#  'Bombay': 85,
#  'allotted': 86,
#  'guerre': 87,
#  'furnish': 88,
#  'contemplating': 89,
#  'sq': 90,
#  'Tantawi': 91,
#  'turnover': 92,
#  'tightly-packed': 93,
#  'counterfeiters': 94,
#  'epidemics': 95,
#  'suit': 96,
#  'downturn': 97,
#  'Antonin': 98,
#  'ghettos': 99,
#  'Cheema': 100,
#  'editorials': 101,
#  'constituencies': 102,
#  'performers': 103,
#  'Miami-based': 104,
#  'presidential-parliamentary': 105,
#  'Shimon': 106,
#  'Front': 107,
#  'interreligious': 108,
#  'Usman': 109,
#  'nutrition': 110,
#  'signing': 111,
#  'over-reliance': 112,
#  'Crumpton': 113,
#  'Additionally': 114,
#  'unlawfully': 115,
#  '616-5': 116,
#  'nascent': 117,
#  'Kuznetsova': 118,
#  'manufactures': 119,
#  'electricity': 120,
#  'interrogations': 121,
#  'Majmaah': 122,
#  'writers': 123,
#  'Actor': 124,
#  'indictments': 125,
#  'provocation': 126,
#  're-planted': 127,
#  'decimated': 128,
#  'best': 129,
#  'al-Assad': 130,
#  'doctor': 131,
#  'hardcourts': 132,
#  'Search': 133,
#  'Superstar': 134,
#  'Yoshimasa': 135,
#  'nomadic': 136,
#  'Shmatko': 137,
#  'simmers': 138,
#  'disputings': 139,
#  'dinner': 140,
#  'apologized': 141,
#  'Traian': 142,
#  'launched': 143,
#  'surging': 144,
#  'Russian-born': 145,
#  'grapes': 146,
#  'Vultures': 147,
#  'two-dozen': 148,
#  'tech': 149,
#  'IWC': 150,
#  'felt': 151,
#  'hailed': 152,
#  'banner': 153,
#  'dissenting': 154,
#  'staggered': 155,
#  'two-thousand': 156,
#  'Salt': 157,
#  'moderates': 158,
#  'pioneering': 159,
#  'misuse': 160,
#  'nationalists': 161,
#  'Mirdamadi': 162,
#  '1862': 163,
#  'Bitar': 164,
#  '2004': 165,
#  'retained': 166,
#  'tightly': 167,
#  'completes': 168,
#  'mandates': 169,
#  'al-Ghazal': 170,
#  'vetoes': 171,
#  'Hoekstra': 172,
#  'Salomi': 173,
#  'Colored': 174,
#  'cordon': 175,
#  'uproar': 176,
#  'Galloway': 177,
#  'biceps': 178,
#  'Michaella': 179,
#  'demotion': 180,
#  'All-Star': 181,
#  'intentionally': 182,
#  'co-principality': 183,
#  'Gobernador': 184,
#  'Cutler': 185,
#  'IMF-recommended': 186,
#  'Timoshenko': 187,
#  'Lott': 188,
#  'Ministries': 189,
#  'exploration': 190,
#  'Adraskan': 191,
#  'SERPENT': 192,
#  'happiness': 193,
#  'Minghe': 194,
#  'flag-draped': 195,
#  'inciting': 196,
#  'mundane': 197,
#  'Durand': 198,
#  'Crowley': 199,
#  'thoughtful': 200,
#  'huntsmen': 201,
#  '355': 202,
#  'Mohamed': 203,
#  'religiously': 204,
#  'disproportionately': 205,
#  'caricatures': 206,
#  'frustrated': 207,
#  'outcry': 208,
#  'crystal': 209,
#  'suicide': 210,
#  'Youssou': 211,
#  'defections': 212,
#  'pontiff': 213,
#  'self-government': 214,
#  'Giants': 215,
#  'Bilfinger': 216,
#  'Palestinian': 217,
#  'revision': 218,
#  'Anglo-Leasing': 219,
#  'Jericho': 220,
#  'Aruba': 221,
#  '217': 222,
#  'Kagame': 223,
#  '27-year-long': 224,
#  'Raul': 225,
#  'Valenica': 226,
#  'Photographs': 227,
#  'Tadic': 228,
#  'potatoes': 229,
#  'Datanalisis': 230,
#  'Tut': 231,
#  'Domodedovo': 232,
#  '10.7': 233,
#  'sets': 234,
#  'Delhi': 235,
#  'moving': 236,
#  'lit': 237,
#  'singer': 238,
#  'Danforth': 239,
#  'Battle': 240,
#  'banned': 241,
#  'processes': 242,
#  'Its': 243,
#  'Nearby': 244,
#  '273': 245,
#  'Moscoso': 246,
#  'facilitating': 247,
#  'Castelgandolfo': 248,
#  'probation': 249,
#  'non-natives': 250,
#  'internal': 251,
#  'exceeded': 252,
#  'ABDALLAHI': 253,
#  'Grammys': 254,
#  '1,82,000': 255,
#  'Perez': 256,
#  'Prithvi': 257,
#  "Dunkin'": 258,
#  'Minya': 259,
#  'agency': 260,
#  'Khetaguri': 261,
#  'Jovicevic': 262,
#  'funds': 263,
#  'Baru': 264,
#  'deposit': 265,
#  'Sentences': 266,
#  'reopens': 267,
#  'Kubba': 268,
#  'chair': 269,
#  'sandstorm': 270,
#  'huddled': 271,
#  'symbolically': 272,
#  'Earthquake': 273,
#  'Encouraged': 274,
#  'replace': 275,
#  'lawmaker': 276,
#  'Atalay': 277,
#  'Lal': 278,
#  'Georg': 279,
#  'levy': 280,
#  'Ramush': 281,
#  'Alam': 282,
#  'grey': 283,
#  '42-year-old': 284,
#  'pro-jobs': 285,
#  'Renate': 286,
#  'realizing': 287,
#  'EFTA': 288,
#  'collapsing': 289,
#  'Palme': 290,
#  'Balah': 291,
#  'tendering': 292,
#  'HARE': 293,
#  'Tortoise': 294,
#  'Abdul-Khalim': 295,
#  'pollsters': 296,
#  'Montana': 297,
#  'resolutions': 298,
#  'Dar': 299,
#  'whites': 300,
#  'floundering': 301,
#  'Unmasking': 302,
#  'rotate': 303,
#  'Wannian': 304,
#  'Carson': 305,
#  '1834': 306,
#  're-locate': 307,
#  'recreation': 308,
#  'Mining': 309,
#  'Challenger': 310,
#  'administration': 311,
#  'precious': 312,
#  'singers': 313,
#  'hike': 314,
#  'lands': 315,
#  'Saudi': 316,
#  'offering': 317,
#  'buses': 318,
#  'complied': 319,
#  'oceanographic': 320,
#  'Fela': 321,
#  '59.4': 322,
#  'impacted': 323,
#  'Europe-wide': 324,
#  'mere': 325,
#  'price-per-carat': 326,
#  'designation': 327,
#  '15,000': 328,
#  'gushing': 329,
#  '44-year-old': 330,
#  'Srichaphan': 331,
#  'Cayman': 332,
#  'Cauca': 333,
#  'Chasseurs-Volontaires': 334,
#  'recently-halted': 335,
#  'crucifixes': 336,
#  'laborers': 337,
#  'red': 338,
#  '1804': 339,
#  'Andaman': 340,
#  'Van': 341,
#  'surveillance': 342,
#  'owner': 343,
#  'Kong': 344,
#  'stone-throwers': 345,
#  '12,012': 346,
#  'Byrd': 347,
#  'KGB': 348,
#  'imam': 349,
#  '298': 350,
#  'plaza': 351,
#  'Okie': 352,
#  'compare': 353,
#  'diluting': 354,
#  'consolidating': 355,
#  'invade': 356,
#  'noncompliant': 357,
#  'Korea\x92s': 358,
#  'icy': 359,
#  'Differences': 360,
#  'servicemembers': 361,
#  'Shakespeare': 362,
#  'Legaspi': 363,
#  'despised': 364,
#  '281-4': 365,
#  'hard-liners': 366,
#  'FISHERMAN': 367,
#  'third-ranked': 368,
#  'Watni': 369,
#  'adapted': 370,
#  'broken': 371,
#  'Beatification': 372,
#  'Macau': 373,
#  '1902': 374,
#  'indicated': 375,
#  'capitalist': 376,
#  'losses': 377,
#  'Beach': 378,
#  '2,50,000': 379,
#  'Soros': 380,
#  'Marcinkiewicz': 381,
#  'Kwazulu-Natal': 382,
#  'countrymen': 383,
#  'exchanging': 384,
#  'trees': 385,
#  'M.C.': 386,
#  'pathology': 387,
#  'clot': 388,
#  'state-funded': 389,
#  'Failure': 390,
#  'gullet-bag': 391,
#  'introduce': 392,
#  'perched': 393,
#  'employ': 394,
#  'Holmes': 395,
#  '602': 396,
#  'stake': 397,
#  'Asset': 398,
#  'editor-in-chief': 399,
#  'denounce': 400,
#  'enemies': 401,
#  'seriously': 402,
#  'wrestler': 403,
#  'emanate': 404,
#  'Bunia': 405,
#  'Streptococcus': 406,
#  'efficiency': 407,
#  'resolution': 408,
#  'Egebank': 409,
#  '10-week': 410,
#  'severance': 411,
#  'inaugurate': 412,
#  'clinics': 413,
#  'Macchiavello': 414,
#  'Papillon': 415,
#  'Water': 416,
#  'pre-trial': 417,
#  'shame': 418,
#  'parked': 419,
#  'Subsequent': 420,
#  'Alexeyeva': 421,
#  'Dignity': 422,
#  'elements': 423,
#  'Nuri': 424,
#  'mid-1999': 425,
#  'anti-Tutsi': 426,
#  'XII': 427,
#  'Editor': 428,
#  'Camilla': 429,
#  'turbine': 430,
#  'Malawai': 431,
#  'canceled': 432,
#  'Manipur': 433,
#  '141': 434,
#  'suis': 435,
#  'fastest': 436,
#  're-assessed': 437,
#  'Manpower': 438,
#  'Thief': 439,
#  'defies': 440,
#  '1.294': 441,
#  'Gulfport': 442,
#  'profiting': 443,
#  'pressed': 444,
#  'Prominent': 445,
#  'age-old': 446,
#  'U.S.-proposed': 447,
#  'hegemony': 448,
#  'lakeside': 449,
#  '11.6': 450,
#  'Windows': 451,
#  'rehearsing': 452,
#  'browsing': 453,
#  'sauntering': 454,
#  'NE': 455,
#  'cyber': 456,
#  'summary': 457,
#  'Alasay': 458,
#  'Pomagalski': 459,
#  'defection': 460,
#  'setback': 461,
#  'cabs': 462,
#  'seconds': 463,
#  'extensively': 464,
#  'show-per-year': 465,
#  'specifically': 466,
#  'uncalculated': 467,
#  'yards': 468,
#  'reassess': 469,
#  'piling': 470,
#  'Crews': 471,
#  'exploiters': 472,
#  'eco-tourism': 473,
#  'mid-1800s': 474,
#  'harmonious': 475,
#  'associates': 476,
#  'home-made': 477,
#  'drilling': 478,
#  'tenge': 479,
#  'left': 480,
#  'automatic': 481,
#  'worsening': 482,
#  'Marty': 483,
#  'McCarthy': 484,
#  'handovers': 485,
#  'formulas': 486,
#  'boosters': 487,
#  'Anti-Terrorism': 488,
#  'mature': 489,
#  'Earle': 490,
#  'hare': 491,
#  'Quan': 492,
#  '570': 493,
#  'Villagers': 494,
#  'Rochus': 495,
#  'constructed': 496,
#  'Obeidi': 497,
#  'Nargis': 498,
#  'Carolina': 499,
#  'Abdel-Al': 500,
#  'incendiary': 501,
#  'Explored': 502,
#  'Dong': 503,
#  'remanded': 504,
#  'Mall': 505,
#  'scoundrel': 506,
#  'Chenembiri': 507,
#  'Guantanamo': 508,
#  'vigil': 509,
#  'Mejia': 510,
#  'Augusto': 511,
#  'whom': 512,
#  'antipathy': 513,
#  '51,000': 514,
#  '52nd': 515,
#  'sufficiently': 516,
#  'embracing': 517,
#  'Propulsion': 518,
#  'deputy': 519,
#  'jungles': 520,
#  'cordons': 521,
#  'high-ranking': 522,
#  'households': 523,
#  'Tine': 524,
#  'militants': 525,
#  'Dave': 526,
#  'Nauru': 527,
#  'mummies': 528,
#  'ex-boyfriend': 529,
#  '1881': 530,
#  'sentenced': 531,
#  'fertile': 532,
#  'Plavia': 533,
#  'Son': 534,
#  'nights': 535,
#  'Geoffrey': 536,
#  'Rostropovich': 537,
#  'Balakot': 538,
#  'towed': 539,
#  'world-number-one': 540,
#  'Goss': 541,
#  'snipers': 542,
#  'dismal': 543,
#  'Stanishev': 544,
#  'crafted': 545,
#  'Ganiyu': 546,
#  'rival': 547,
#  'Mikulski': 548,
#  'Bangla': 549,
#  'sickness': 550,
#  'Laden': 551,
#  'storing': 552,
#  'pill': 553,
#  'Damiri': 554,
#  'Crow': 555,
#  'Islanders': 556,
#  'chocolate': 557,
#  'Ratnayke': 558,
#  'OneRepublic': 559,
#  'Center-left': 560,
#  'president': 561,
#  'pencil': 562,
#  'bailout': 563,
#  'Sohail': 564,
#  'dog': 565,
#  'nations': 566,
#  '90,000': 567,
#  'candle': 568,
#  'League-Nawaz': 569,
#  'Rompuy': 570,
#  'tight': 571,
#  'Venezuelan': 572,
#  'wildly': 573,
#  'Balenciaga': 574,
#  'foreign-born': 575,
#  'Rudolph': 576,
#  'toxicology': 577,
#  'EU-backed': 578,
#  'Iskander-E': 579,
#  'summer': 580,
#  'Armenian': 581,
#  'umpire': 582,
#  'wallets': 583,
#  'wretched': 584,
#  'X-rays': 585,
#  'Community': 586,
#  'boycotting': 587,
#  'enduring': 588,
#  'protracted': 589,
#  'Norway': 590,
#  'sadness': 591,
#  'Album': 592,
#  'Success': 593,
#  'engagement': 594,
#  'assailants': 595,
#  'Baqer': 596,
#  'chips': 597,
#  'robustly': 598,
#  'Palm': 599,
#  'astronomers': 600,
#  'normalizing': 601,
#  'investigated': 602,
#  'Hsieh': 603,
#  '2,17,000': 604,
#  '84.9': 605,
#  'Working': 606,
#  'earthenware': 607,
#  'PSV': 608,
#  'disarmed': 609,
#  'employed': 610,
#  'Giuliana': 611,
#  'Qaumi': 612,
#  'tires': 613,
#  'sugar-based': 614,
#  'Constitution': 615,
#  'forgotten': 616,
#  'Medicare': 617,
#  'rivalry': 618,
#  'stadiums': 619,
#  'congress': 620,
#  'Shurja': 621,
#  'Wong': 622,
#  'Chihuahua': 623,
#  '555': 624,
#  'Owen': 625,
#  'phony': 626,
#  'pro-reformist': 627,
#  'poised': 628,
#  'Shooting': 629,
#  'scenery': 630,
#  '163-seat': 631,
#  'Sidon': 632,
#  'incited': 633,
#  'Ronit': 634,
#  'day-visit': 635,
#  'minority': 636,
#  'Wal-Mart': 637,
#  'Bandundu': 638,
#  'rehabilitation': 639,
#  '55-to-45': 640,
#  'embark': 641,
#  'Dihok': 642,
#  'revamp': 643,
#  'allots': 644,
#  'al-Hasan': 645,
#  'Dukeness': 646,
#  'pursuant': 647,
#  'lateral': 648,
#  'hosted': 649,
#  'Shipping': 650,
#  'cohesion': 651,
#  'fascists': 652,
#  'mud': 653,
#  'poorly': 654,
#  'Remote': 655,
#  'sailed': 656,
#  'batter': 657,
#  'policemen': 658,
#  'laden': 659,
#  'Kohdamani': 660,
#  'Legislation': 661,
#  'journal': 662,
#  'environments': 663,
#  'disrupt': 664,
#  'methane': 665,
#  'two-decade': 666,
#  'pickle-fork': 667,
#  'says': 668,
#  'Arts': 669,
#  'crashed': 670,
#  'ridicule': 671,
#  'propulsion': 672,
#  'thought': 673,
#  'Paranavithana': 674,
#  'Liv-Grete': 675,
#  'Frode': 676,
#  'ITV': 677,
#  'wraps': 678,
#  'Aichatou': 679,
#  'Phil': 680,
#  'dynastic': 681,
#  'decorated': 682,
#  'Medvedev': 683,
#  'emergencies': 684,
#  'technicians': 685,
#  'disturbed': 686,
#  'Nations-backed': 687,
#  'gulf': 688,
#  'Torbat-e-Heydariyeh': 689,
#  'Jalani': 690,
#  'Pigeons': 691,
#  'Heineken': 692,
#  'edict': 693,
#  'al-Bahlul': 694,
#  'Anti-Doping': 695,
#  '4,480': 696,
#  'ties': 697,
#  'inspectors': 698,
#  'Flying': 699,
#  'Transocean': 700,
#  'collects': 701,
#  'Whales': 702,
#  'doomed': 703,
#  'banjo': 704,
#  'dedication': 705,
#  'closely-watched': 706,
#  'Cookstown': 707,
#  'flooding': 708,
#  'navigation': 709,
#  'called': 710,
#  'hyper-inflation': 711,
#  'government-appointed': 712,
#  'repatriation': 713,
#  'Fund': 714,
#  'Oezil': 715,
#  'shoulder': 716,
#  'toured': 717,
#  'Rico': 718,
#  'back': 719,
#  'incoming': 720,
#  'subjugation': 721,
#  'reportedly': 722,
#  'US-VISIT': 723,
#  'detractors': 724,
#  'Melissa': 725,
#  'Jong-Chul': 726,
#  'Trustco': 727,
#  'RPF': 728,
#  'paved': 729,
#  'French': 730,
#  'not': 731,
#  'Sibghatullah': 732,
#  'Davis': 733,
#  'Frank': 734,
#  'malfunctioned': 735,
#  'co-exist': 736,
#  'Kamuzu': 737,
#  'corruption': 738,
#  'uncalled': 739,
#  'Portman': 740,
#  'appoint': 741,
#  'portraying': 742,
#  'northeast': 743,
#  'Melanesians': 744,
#  'bears': 745,
#  'justly': 746,
#  '1916': 747,
#  'merit': 748,
#  'laws': 749,
#  'neighboring': 750,
#  'Belaroussi': 751,
#  'prosecutor': 752,
#  '36th': 753,
#  'diameter': 754,
#  'Iranativu': 755,
#  'Susy': 756,
#  'Irish': 757,
#  'Vavi': 758,
#  'devised': 759,
#  'streets': 760,
#  'Stocks': 761,
#  'Taleban-linked': 762,
#  'beneficial': 763,
#  'Jane': 764,
#  'Waitangi': 765,
#  'Obeid': 766,
#  '2,781': 767,
#  'spiral': 768,
#  'sensationalizing': 769,
#  'Sister': 770,
#  'Idrissu': 771,
#  'substantiate': 772,
#  'bunkers': 773,
#  'nutmeg': 774,
#  'natives': 775,
#  'Expatriates': 776,
#  'mid-May': 777,
#  'Meerut': 778,
#  'Yoshie': 779,
#  'No': 780,
#  'Mario': 781,
#  'Pashtoonkhwa': 782,
#  'frailty': 783,
#  'goals': 784,
#  'Lashkar': 785,
#  'Linux-based': 786,
#  'Areva': 787,
#  'becomes': 788,
#  'expedite': 789,
#  'Jalali': 790,
#  'ultimatum': 791,
#  'publishes': 792,
#  'Harun': 793,
#  'Nabeel': 794,
#  'Louise': 795,
#  'Tharanga': 796,
#  'settle': 797,
#  'Demilitarized': 798,
#  'Geagea': 799,
#  'ceded': 800,
#  'Bakwa': 801,
#  'questioning': 802,
#  'Bennett': 803,
#  'Dobrynska': 804,
#  'Vera': 805,
#  'righteous': 806,
#  'deadlocked': 807,
#  'context': 808,
#  'Lawyer': 809,
#  'simple': 810,
#  'Artemisian-based': 811,
#  'benzene': 812,
#  'Chaparhar': 813,
#  'opium-traffickers': 814,
#  'pro-India': 815,
#  'Arson': 816,
#  'Bouna': 817,
#  'congratuatlions': 818,
#  'Dan': 819,
#  'Himalayas': 820,
#  'quashed': 821,
#  'ranchers': 822,
#  'Communication': 823,
#  'repel': 824,
#  'haven': 825,
#  'Young': 826,
#  'fraud': 827,
#  'plays': 828,
#  'shirt': 829,
#  'third-place': 830,
#  'highly-indebted': 831,
#  'MILOSEVIC': 832,
#  'Youssef': 833,
#  'Israeli-Hizballah': 834,
#  'exported': 835,
#  'joyous': 836,
#  'weaponization': 837,
#  'ostrich': 838,
#  'embraced': 839,
#  'mild': 840,
#  'Blears': 841,
#  '54,000': 842,
#  'Saeedlou': 843,
#  'ignite': 844,
#  'interpreter': 845,
#  'Citing': 846,
#  'pastoral': 847,
#  'Schoomaker': 848,
#  'landless': 849,
#  'extorting': 850,
#  'underwater': 851,
#  'Quartet': 852,
#  'Spiegel': 853,
#  '375': 854,
#  'plant': 855,
#  'grandmother': 856,
#  'Bhutanese': 857,
#  'Costa': 858,
#  'adopts': 859,
#  'Padilla': 860,
#  'unloaded': 861,
#  'KFM': 862,
#  'shielding': 863,
#  'continuing': 864,
#  'Accidents': 865,
#  'priesthood': 866,
#  'common-sense': 867,
#  'POMEGRANATE': 868,
#  'Memphis': 869,
#  'Cock': 870,
#  'Seydou': 871,
#  'welfare-dependent': 872,
#  'entrenched': 873,
#  'Dinari': 874,
#  'DEBY': 875,
#  'meteorological': 876,
#  'Stamford': 877,
#  'Nihal': 878,
#  'quantity': 879,
#  'forgive': 880,
#  'annotations': 881,
#  'Hudson': 882,
#  'demerits': 883,
#  'Nirvana': 884,
#  'propose': 885,
#  'Flutur': 886,
#  'Midwestern': 887,
#  'deactivated': 888,
#  'recommendations': 889,
#  'spaceship': 890,
#  'city': 891,
#  'saving': 892,
#  'snowstorm': 893,
#  'NATO': 894,
#  'revere': 895,
#  'Preaching': 896,
#  'abandons': 897,
#  'Copper': 898,
#  'fair': 899,
#  'necessarily': 900,
#  'offspring': 901,
#  'Although': 902,
#  'obscene': 903,
#  'resurrect': 904,
#  'Cedatos-Gallup': 905,
#  'blockbuster': 906,
#  'Asadabad': 907,
#  '1607': 908,
#  'beer': 909,
#  'Aamodt': 910,
#  'unconfirmed': 911,
#  'rebut': 912,
#  'prescribed': 913,
#  'Roemer': 914,
#  'overturned': 915,
#  'Godfrey': 916,
#  'robot': 917,
#  'becoming': 918,
#  'salesman': 919,
#  '502nd': 920,
#  'Simeus': 921,
#  'Tarija': 922,
#  'specifies': 923,
#  'salvaging': 924,
#  'promised': 925,
#  'drill': 926,
#  'instructions': 927,
#  '7.6': 928,
#  '...': 929,
#  'thinned': 930,
#  'Violators': 931,
#  'thoughts': 932,
#  'Zonen': 933,
#  'Sahrawi': 934,
#  'warehouse': 935,
#  'Buoyed': 936,
#  'neurological': 937,
#  'HARDLY': 938,
#  'Station': 939,
#  'Belkadi': 940,
#  'patented': 941,
#  'literally': 942,
#  'stumbling': 943,
#  'Eric': 944,
#  'glue': 945,
#  'post-civil': 946,
#  'closures': 947,
#  'partitioned': 948,
#  'describing': 949,
#  'Petrasevic': 950,
#  'seas': 951,
#  'dengue': 952,
#  'Moheli': 953,
#  'consumers': 954,
#  'Saeed': 955,
#  'Marra': 956,
#  'thundershowers': 957,
#  'locked': 958,
#  '40-year': 959,
#  'salinity': 960,
#  'commonwealth': 961,
#  'precinct': 962,
#  'attorneys': 963,
#  'wounding': 964,
#  'Elgon': 965,
#  'SPENDTHRIFT': 966,
#  'indicating': 967,
#  '542': 968,
#  'propaganda': 969,
#  'Jalalzadeh': 970,
#  'well-trained': 971,
#  'interacted': 972,
#  'Socialist': 973,
#  'pact': 974,
#  'Robben': 975,
#  'admiral': 976,
#  'looser': 977,
#  'Locally': 978,
#  'kings': 979,
#  'hypertension': 980,
#  'Chad-Sudan': 981,
#  'Farewell': 982,
#  'reopening': 983,
#  'Ray': 984,
#  'evacuees': 985,
#  'completed': 986,
#  'carcasses': 987,
#  'Selig': 988,
#  'profit': 989,
#  'Dawa': 990,
#  'Desai': 991,
#  'premier': 992,
#  'Abraham': 993,
#  'Haniyeh': 994,
#  'Era': 995,
#  'Al-Zarqawi': 996,
#  'Craybas': 997,
#  'Jacob': 998,
#  'enhancing': 999,
#  'near-by': 1000,
#  ...}

# %%
max_len=50
X=[[word2idx[w[0]] for w in s] for s in sentences]
X=pad_sequences(maxlen=max_len, sequences=X, padding="post", value=num_words-1)
y=[[tag2idx[w[2]] for w in s] for s in sentences]
y=pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

# %%
x_train, x_test, y_train, y_test=train_test_split(X, y, test_size=0.25, random_state=1)

# %%
input_word=Input(shape=(max_len,))
model=Embedding(input_dim=num_words, output_dim=50, input_length=max_len)(input_word)
model=SpatialDropout1D(0.1)(model)
model=Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)
out=TimeDistributed(Dense(num_tags, activation="softmax"))(model)
model=Model(input_word, out)
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 50)]              0
#
#  embedding (Embedding)       (None, 50, 50)            1758950
#
#  spatial_dropout1d (SpatialD  (None, 50, 50)           0
#  ropout1D)
#
#  bidirectional (Bidirectiona  (None, 50, 200)          120800
#  l)
#
#  time_distributed (TimeDistr  (None, 50, 17)           3417
#  ibuted)
#
# =================================================================
# Total params: 1,883,167
# Trainable params: 1,883,167
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
chkpt=ModelCheckpoint("model_weights.h5", monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=True, mode='min')
early_stopping=EarlyStopping(monitor='val_accuracy', min_delta=0, patience=1, verbose=0, mode='max', baseline=None, restore_best_weights=False)
history=model.fit(x=x_train, y=y_train, validation_data=(x_test,y_test), batch_size=32, epochs=5, verbose=1)
# Out:
# Epoch 1/5
# 1125/1125 [==============================] - 456s 402ms/step - loss: 0.1859 - accuracy: 0.9573 - val_loss: 0.0660 - val_accuracy: 0.9812
# Epoch 2/5
# 1125/1125 [==============================] - 461s 409ms/step - loss: 0.0507 - accuracy: 0.9851 - val_loss: 0.0518 - val_accuracy: 0.9850
# Epoch 3/5
# 1125/1125 [==============================] - 441s 392ms/step - loss: 0.0372 - accuracy: 0.9887 - val_loss: 0.0488 - val_accuracy: 0.9857
# Epoch 4/5
# 1125/1125 [==============================] - 432s 384ms/step - loss: 0.0308 - accuracy: 0.9903 - val_loss: 0.0495 - val_accuracy: 0.9852
# Epoch 5/5
# 1125/1125 [==============================] - 436s 387ms/step - loss: 0.0268 - accuracy: 0.9915 - val_loss: 0.0512 - val_accuracy: 0.9858

# %%
model.evaluate(x_test, y_test)
# Out:
# 375/375 [==============================] - 20s 52ms/step - loss: 0.0512 - accuracy: 0.9858
# [0.05117364227771759, 0.9857881665229797]

# %%
i=np.random.randint(0, x_test.shape[0]) 
p=model.predict(np.array([x_test[i]]))
p=np.argmax(p, axis=-1)
y_true = y_test[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" *30)
for w, true, pred in zip(x_test[i], y_true, p[0]):
    print("{:15}{}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# 1/1 [==============================] - 0s 108ms/step
# Word           True 	 Pred
#
# ------------------------------
# Meanwhile      O	O
# ,              O	O
# Bulgaria       B-geo	B-geo
# says           O	O
# U.S.           B-geo	B-geo
# forces         O	O
# have           O	O
# admitted       O	O
# responsibility O	O
# for            O	O
# the            O	O
# "              O	O
# friendly-fire  O	O
# "              O	O
# death          O	O
# of             O	O
# a              O	O
# Bulgarian      B-gpe	B-gpe
# soldier        O	O
# in             O	O
# southern       B-geo	B-geo
# Iraq           I-geo	I-geo
# a              O	O
# week           O	O
# ago            O	O
# .              O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
# Faisal         O	O
